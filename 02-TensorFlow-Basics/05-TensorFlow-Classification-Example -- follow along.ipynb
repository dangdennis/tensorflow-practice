# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max()-x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
import tensorflow as tf

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group', ['A','B','C','D'])

# %%
assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)
assigned_group
# Out:
# _HashedCategoricalColumn(key='Group', hash_bucket_size=10, dtype=tf.string)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_bucket = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %%
age_bucket
# Out:
# _BucketizedColumn(source_column=_NumericColumn(key='Age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), boundaries=(20, 30, 40, 50, 60, 70, 80))

# %%
feat_cols = [num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_pedigree, assigned_group, age_bucket]

# %%
# Train test split

# %%
x_data = diabetes.drop('Class', axis=1)
x_data.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age Group
# 0  0.500745  0.234415   50     B
# 1  0.396423  0.116567   31     C
# 2  0.347243  0.253629   32     B
# 3  0.418778  0.038002   21     B
# 4  0.642325  0.943638   33     C

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, labels, test_size=0.3, random_state=101)

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train, y=y_train, batch_size=10, num_epochs=1000, shuffle=True)

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Dennis\AppData\Local\Temp\tmpnzuq85nb
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Dennis\\AppData\\Local\\Temp\\tmpnzuq85nb', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002008FBA8278>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Dennis\AppData\Local\Temp\tmpnzuq85nb\model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 386.88
# INFO:tensorflow:loss = 6.356332, step = 101 (0.260 sec)
# INFO:tensorflow:global_step/sec: 789.515
# INFO:tensorflow:loss = 5.2836084, step = 201 (0.127 sec)
# INFO:tensorflow:global_step/sec: 737.26
# INFO:tensorflow:loss = 5.551859, step = 301 (0.135 sec)
# INFO:tensorflow:global_step/sec: 731.88
# INFO:tensorflow:loss = 4.1128016, step = 401 (0.137 sec)
# INFO:tensorflow:global_step/sec: 789.506
# INFO:tensorflow:loss = 4.7831078, step = 501 (0.127 sec)
# INFO:tensorflow:global_step/sec: 788.903
# INFO:tensorflow:loss = 6.7741776, step = 601 (0.127 sec)
# INFO:tensorflow:global_step/sec: 753.889
# INFO:tensorflow:loss = 4.449107, step = 701 (0.133 sec)
# INFO:tensorflow:global_step/sec: 777.27
# INFO:tensorflow:loss = 6.9279757, step = 801 (0.130 sec)
# INFO:tensorflow:global_step/sec: 724.374
# INFO:tensorflow:loss = 5.2025805, step = 901 (0.138 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Dennis\AppData\Local\Temp\tmpnzuq85nb\model.ckpt.
# INFO:tensorflow:Loss for final step: 6.73057.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-07-03:34:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Dennis\AppData\Local\Temp\tmpnzuq85nb\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-07-03:34:49
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.7316017, accuracy_baseline = 0.64935064, auc = 0.80740744, auc_precision_recall = 0.65295845, average_loss = 0.52262956, global_step = 1000, label/mean = 0.35064936, loss = 5.0303097, precision = 0.6507937, prediction/mean = 0.3662567, recall = 0.50617284

# %%
results
# Out:
# {'accuracy': 0.7316017,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.80740744,
#  'auc_precision_recall': 0.65295845,
#  'average_loss': 0.52262956,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 5.0303097,
#  'precision': 0.6507937,
#  'prediction/mean': 0.3662567,
#  'recall': 0.50617284}

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(x=X_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
predictions = model.predict(pred_input_func)

# %%
my_pred = list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Dennis\AppData\Local\Temp\tmpnzuq85nb\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
my_pred
# Out:
# [{'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49638638], dtype=float32),
#   'logits': array([-0.01445472], dtype=float32),
#   'probabilities': array([0.50361365, 0.4963864 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6244329], dtype=float32),
#   'logits': array([0.5084069], dtype=float32),
#   'probabilities': array([0.37556705, 0.6244329 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3523027], dtype=float32),
#   'logits': array([-0.6089327], dtype=float32),
#   'probabilities': array([0.64769727, 0.3523027 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35245982], dtype=float32),
#   'logits': array([-0.6082442], dtype=float32),
#   'probabilities': array([0.64754015, 0.35245982], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15168948], dtype=float32),
#   'logits': array([-1.7214112], dtype=float32),
#   'probabilities': array([0.84831053, 0.15168948], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.73440707], dtype=float32),
#   'logits': array([1.0170985], dtype=float32),
#   'probabilities': array([0.26559296, 0.73440707], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58957875], dtype=float32),
#   'logits': array([0.36222434], dtype=float32),
#   'probabilities': array([0.4104212 , 0.58957875], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30483928], dtype=float32),
#   'logits': array([-0.82435834], dtype=float32),
#   'probabilities': array([0.69516075, 0.3048393 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2560194], dtype=float32),
#   'logits': array([-1.0667617], dtype=float32),
#   'probabilities': array([0.7439806 , 0.25601938], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23300447], dtype=float32),
#   'logits': array([-1.1914234], dtype=float32),
#   'probabilities': array([0.76699555, 0.23300447], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1395209], dtype=float32),
#   'logits': array([-1.8192749], dtype=float32),
#   'probabilities': array([0.8604791, 0.1395209], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16347493], dtype=float32),
#   'logits': array([-1.6325969], dtype=float32),
#   'probabilities': array([0.8365251 , 0.16347493], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2757087], dtype=float32),
#   'logits': array([-0.9658488], dtype=float32),
#   'probabilities': array([0.7242913, 0.2757087], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55486614], dtype=float32),
#   'logits': array([0.2203517], dtype=float32),
#   'probabilities': array([0.44513392, 0.55486614], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19278811], dtype=float32),
#   'logits': array([-1.4319944], dtype=float32),
#   'probabilities': array([0.8072119 , 0.19278812], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37758383], dtype=float32),
#   'logits': array([-0.49981636], dtype=float32),
#   'probabilities': array([0.6224162 , 0.37758386], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4078385], dtype=float32),
#   'logits': array([-0.37290812], dtype=float32),
#   'probabilities': array([0.5921615, 0.4078385], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13782495], dtype=float32),
#   'logits': array([-1.8334739], dtype=float32),
#   'probabilities': array([0.86217505, 0.13782495], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34776187], dtype=float32),
#   'logits': array([-0.6288918], dtype=float32),
#   'probabilities': array([0.65223813, 0.34776184], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14774863], dtype=float32),
#   'logits': array([-1.7523692], dtype=float32),
#   'probabilities': array([0.85225135, 0.14774862], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23467918], dtype=float32),
#   'logits': array([-1.1820757], dtype=float32),
#   'probabilities': array([0.76532084, 0.23467919], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31949055], dtype=float32),
#   'logits': array([-0.75611395], dtype=float32),
#   'probabilities': array([0.68050945, 0.31949058], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63674885], dtype=float32),
#   'logits': array([0.5612806], dtype=float32),
#   'probabilities': array([0.36325124, 0.63674885], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22758201], dtype=float32),
#   'logits': array([-1.2220153], dtype=float32),
#   'probabilities': array([0.772418  , 0.22758201], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19615999], dtype=float32),
#   'logits': array([-1.4104697], dtype=float32),
#   'probabilities': array([0.80384   , 0.19615997], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7759551], dtype=float32),
#   'logits': array([1.2422482], dtype=float32),
#   'probabilities': array([0.2240449, 0.7759551], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18650518], dtype=float32),
#   'logits': array([-1.4728805], dtype=float32),
#   'probabilities': array([0.8134948 , 0.18650518], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3450127], dtype=float32),
#   'logits': array([-0.64103466], dtype=float32),
#   'probabilities': array([0.65498734, 0.3450127 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10767457], dtype=float32),
#   'logits': array([-2.1147175], dtype=float32),
#   'probabilities': array([0.89232546, 0.10767457], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5680578], dtype=float32),
#   'logits': array([0.27393138], dtype=float32),
#   'probabilities': array([0.4319422, 0.5680578], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.93985665], dtype=float32),
#   'logits': array([2.7489967], dtype=float32),
#   'probabilities': array([0.06014334, 0.93985665], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38422832], dtype=float32),
#   'logits': array([-0.47163922], dtype=float32),
#   'probabilities': array([0.61577165, 0.38422835], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34119383], dtype=float32),
#   'logits': array([-0.65797865], dtype=float32),
#   'probabilities': array([0.65880615, 0.34119383], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5539391], dtype=float32),
#   'logits': array([0.21659935], dtype=float32),
#   'probabilities': array([0.44606087, 0.5539391 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26652986], dtype=float32),
#   'logits': array([-1.0123006], dtype=float32),
#   'probabilities': array([0.73347014, 0.26652986], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3577893], dtype=float32),
#   'logits': array([-0.58497214], dtype=float32),
#   'probabilities': array([0.64221066, 0.3577893 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48026213], dtype=float32),
#   'logits': array([-0.07899237], dtype=float32),
#   'probabilities': array([0.51973784, 0.4802622 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.62738276], dtype=float32),
#   'logits': array([0.5210049], dtype=float32),
#   'probabilities': array([0.3726173 , 0.62738276], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7537708], dtype=float32),
#   'logits': array([1.1188258], dtype=float32),
#   'probabilities': array([0.24622914, 0.7537708 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30160508], dtype=float32),
#   'logits': array([-0.83966637], dtype=float32),
#   'probabilities': array([0.69839495, 0.30160505], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19341925], dtype=float32),
#   'logits': array([-1.427944], dtype=float32),
#   'probabilities': array([0.8065808 , 0.19341925], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5325009], dtype=float32),
#   'logits': array([0.13018715], dtype=float32),
#   'probabilities': array([0.46749914, 0.5325009 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16997525], dtype=float32),
#   'logits': array([-1.5858027], dtype=float32),
#   'probabilities': array([0.8300248 , 0.16997525], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5072796], dtype=float32),
#   'logits': array([0.02912021], dtype=float32),
#   'probabilities': array([0.4927205, 0.5072796], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15259746], dtype=float32),
#   'logits': array([-1.7143724], dtype=float32),
#   'probabilities': array([0.8474025 , 0.15259746], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11646962], dtype=float32),
#   'logits': array([-2.0262952], dtype=float32),
#   'probabilities': array([0.8835303 , 0.11646962], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5892876], dtype=float32),
#   'logits': array([0.36102116], dtype=float32),
#   'probabilities': array([0.4107124, 0.5892876], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19360611], dtype=float32),
#   'logits': array([-1.4267466], dtype=float32),
#   'probabilities': array([0.8063939 , 0.19360612], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21540031], dtype=float32),
#   'logits': array([-1.2926755], dtype=float32),
#   'probabilities': array([0.78459966, 0.21540028], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13101529], dtype=float32),
#   'logits': array([-1.8920115], dtype=float32),
#   'probabilities': array([0.8689847 , 0.13101529], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18179199], dtype=float32),
#   'logits': array([-1.5042535], dtype=float32),
#   'probabilities': array([0.818208  , 0.18179198], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2590373], dtype=float32),
#   'logits': array([-1.0509782], dtype=float32),
#   'probabilities': array([0.74096274, 0.25903732], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26898688], dtype=float32),
#   'logits': array([-0.99976873], dtype=float32),
#   'probabilities': array([0.7310131, 0.2689869], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35358903], dtype=float32),
#   'logits': array([-0.60330033], dtype=float32),
#   'probabilities': array([0.646411, 0.353589], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13687803], dtype=float32),
#   'logits': array([-1.8414658], dtype=float32),
#   'probabilities': array([0.8631219 , 0.13687801], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23707233], dtype=float32),
#   'logits': array([-1.168798], dtype=float32),
#   'probabilities': array([0.76292765, 0.23707232], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22450386], dtype=float32),
#   'logits': array([-1.2396102], dtype=float32),
#   'probabilities': array([0.7754962 , 0.22450386], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23125526], dtype=float32),
#   'logits': array([-1.2012368], dtype=float32),
#   'probabilities': array([0.76874477, 0.23125526], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47027144], dtype=float32),
#   'logits': array([-0.11905468], dtype=float32),
#   'probabilities': array([0.5297286 , 0.47027147], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16804989], dtype=float32),
#   'logits': array([-1.5995116], dtype=float32),
#   'probabilities': array([0.8319501 , 0.16804989], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24816358], dtype=float32),
#   'logits': array([-1.1084306], dtype=float32),
#   'probabilities': array([0.7518364, 0.2481636], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6300299], dtype=float32),
#   'logits': array([0.5323452], dtype=float32),
#   'probabilities': array([0.36997008, 0.6300299 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61930084], dtype=float32),
#   'logits': array([0.48658168], dtype=float32),
#   'probabilities': array([0.3806992 , 0.61930084], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47686133], dtype=float32),
#   'logits': array([-0.09262079], dtype=float32),
#   'probabilities': array([0.52313864, 0.47686133], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38847983], dtype=float32),
#   'logits': array([-0.4537068], dtype=float32),
#   'probabilities': array([0.61152023, 0.38847983], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47444034], dtype=float32),
#   'logits': array([-0.10232776], dtype=float32),
#   'probabilities': array([0.52555966, 0.47444037], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19495103], dtype=float32),
#   'logits': array([-1.4181547], dtype=float32),
#   'probabilities': array([0.805049  , 0.19495103], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21034653], dtype=float32),
#   'logits': array([-1.3228378], dtype=float32),
#   'probabilities': array([0.7896535 , 0.21034653], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15972698], dtype=float32),
#   'logits': array([-1.6602609], dtype=float32),
#   'probabilities': array([0.840273  , 0.15972698], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14194193], dtype=float32),
#   'logits': array([-1.7992537], dtype=float32),
#   'probabilities': array([0.85805804, 0.14194192], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6051457], dtype=float32),
#   'logits': array([0.42695248], dtype=float32),
#   'probabilities': array([0.39485428, 0.6051457 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25069535], dtype=float32),
#   'logits': array([-1.0949073], dtype=float32),
#   'probabilities': array([0.74930465, 0.25069532], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40112075], dtype=float32),
#   'logits': array([-0.40079737], dtype=float32),
#   'probabilities': array([0.5988792 , 0.40112075], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55548936], dtype=float32),
#   'logits': array([0.2228756], dtype=float32),
#   'probabilities': array([0.44451058, 0.55548936], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33534622], dtype=float32),
#   'logits': array([-0.6841028], dtype=float32),
#   'probabilities': array([0.6646538 , 0.33534622], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6238979], dtype=float32),
#   'logits': array([0.50612617], dtype=float32),
#   'probabilities': array([0.37610206, 0.6238979 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13223384], dtype=float32),
#   'logits': array([-1.8813504], dtype=float32),
#   'probabilities': array([0.8677662 , 0.13223386], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61695683], dtype=float32),
#   'logits': array([0.47665143], dtype=float32),
#   'probabilities': array([0.38304314, 0.61695683], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13216747], dtype=float32),
#   'logits': array([-1.8819289], dtype=float32),
#   'probabilities': array([0.86783254, 0.13216747], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5346134], dtype=float32),
#   'logits': array([0.13867533], dtype=float32),
#   'probabilities': array([0.4653866, 0.5346134], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37589055], dtype=float32),
#   'logits': array([-0.5070277], dtype=float32),
#   'probabilities': array([0.62410945, 0.37589058], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17347994], dtype=float32),
#   'logits': array([-1.5611622], dtype=float32),
#   'probabilities': array([0.82652   , 0.17347993], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5383331], dtype=float32),
#   'logits': array([0.15363407], dtype=float32),
#   'probabilities': array([0.46166682, 0.5383331 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57384795], dtype=float32),
#   'logits': array([0.2975682], dtype=float32),
#   'probabilities': array([0.42615205, 0.57384795], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55130845], dtype=float32),
#   'logits': array([0.20595872], dtype=float32),
#   'probabilities': array([0.44869158, 0.55130845], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18097098], dtype=float32),
#   'logits': array([-1.5097828], dtype=float32),
#   'probabilities': array([0.819029  , 0.18097098], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35084796], dtype=float32),
#   'logits': array([-0.61531395], dtype=float32),
#   'probabilities': array([0.64915204, 0.350848  ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16426647], dtype=float32),
#   'logits': array([-1.62682], dtype=float32),
#   'probabilities': array([0.8357336 , 0.16426647], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.698773], dtype=float32),
#   'logits': array([0.841462], dtype=float32),
#   'probabilities': array([0.30122694, 0.698773  ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8125342], dtype=float32),
#   'logits': array([1.4665617], dtype=float32),
#   'probabilities': array([0.18746579, 0.8125342 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6041307], dtype=float32),
#   'logits': array([0.42270648], dtype=float32),
#   'probabilities': array([0.39586928, 0.6041307 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22834149], dtype=float32),
#   'logits': array([-1.2176998], dtype=float32),
#   'probabilities': array([0.7716585, 0.2283415], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45231032], dtype=float32),
#   'logits': array([-0.19134027], dtype=float32),
#   'probabilities': array([0.5476897 , 0.45231038], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35069114], dtype=float32),
#   'logits': array([-0.61600256], dtype=float32),
#   'probabilities': array([0.64930886, 0.35069117], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41877982], dtype=float32),
#   'logits': array([-0.3277843], dtype=float32),
#   'probabilities': array([0.5812202 , 0.41877985], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3262789], dtype=float32),
#   'logits': array([-0.72506374], dtype=float32),
#   'probabilities': array([0.67372113, 0.3262789 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41569704], dtype=float32),
#   'logits': array([-0.34046298], dtype=float32),
#   'probabilities': array([0.584303  , 0.41569704], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16536552], dtype=float32),
#   'logits': array([-1.6188357], dtype=float32),
#   'probabilities': array([0.8346345, 0.1653655], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54644305], dtype=float32),
#   'logits': array([0.18630934], dtype=float32),
#   'probabilities': array([0.4535569 , 0.54644305], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5394931], dtype=float32),
#   'logits': array([0.15830219], dtype=float32),
#   'probabilities': array([0.4605069, 0.5394931], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2578641], dtype=float32),
#   'logits': array([-1.0570997], dtype=float32),
#   'probabilities': array([0.74213594, 0.25786412], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19000256], dtype=float32),
#   'logits': array([-1.4499935], dtype=float32),
#   'probabilities': array([0.80999744, 0.19000258], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18782502], dtype=float32),
#   'logits': array([-1.464205], dtype=float32),
#   'probabilities': array([0.812175  , 0.18782501], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29515424], dtype=float32),
#   'logits': array([-0.87048095], dtype=float32),
#   'probabilities': array([0.7048458 , 0.29515424], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3520105], dtype=float32),
#   'logits': array([-0.6102135], dtype=float32),
#   'probabilities': array([0.6479895 , 0.35201052], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1474221], dtype=float32),
#   'logits': array([-1.7549646], dtype=float32),
#   'probabilities': array([0.8525779 , 0.14742212], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30394587], dtype=float32),
#   'logits': array([-0.8285779], dtype=float32),
#   'probabilities': array([0.69605416, 0.30394584], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22888573], dtype=float32),
#   'logits': array([-1.2146137], dtype=float32),
#   'probabilities': array([0.77111423, 0.22888573], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10085075], dtype=float32),
#   'logits': array([-2.1878073], dtype=float32),
#   'probabilities': array([0.8991493 , 0.10085075], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13382849], dtype=float32),
#   'logits': array([-1.8675239], dtype=float32),
#   'probabilities': array([0.86617154, 0.13382849], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7430849], dtype=float32),
#   'logits': array([1.0620645], dtype=float32),
#   'probabilities': array([0.25691512, 0.7430849 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18967709], dtype=float32),
#   'logits': array([-1.4521097], dtype=float32),
#   'probabilities': array([0.81032294, 0.1896771 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1417318], dtype=float32),
#   'logits': array([-1.8009801], dtype=float32),
#   'probabilities': array([0.8582682, 0.1417318], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1545943], dtype=float32),
#   'logits': array([-1.6990124], dtype=float32),
#   'probabilities': array([0.8454057, 0.1545943], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49276844], dtype=float32),
#   'logits': array([-0.02892828], dtype=float32),
#   'probabilities': array([0.5072316 , 0.49276847], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44716814], dtype=float32),
#   'logits': array([-0.21211916], dtype=float32),
#   'probabilities': array([0.5528318 , 0.44716814], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.258574], dtype=float32),
#   'logits': array([-1.0533934], dtype=float32),
#   'probabilities': array([0.741426, 0.258574], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41347063], dtype=float32),
#   'logits': array([-0.3496362], dtype=float32),
#   'probabilities': array([0.5865294 , 0.41347066], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20390727], dtype=float32),
#   'logits': array([-1.3620503], dtype=float32),
#   'probabilities': array([0.7960927 , 0.20390727], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24939758], dtype=float32),
#   'logits': array([-1.1018279], dtype=float32),
#   'probabilities': array([0.7506024 , 0.24939756], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5418744], dtype=float32),
#   'logits': array([0.1678909], dtype=float32),
#   'probabilities': array([0.4581256, 0.5418744], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46973854], dtype=float32),
#   'logits': array([-0.12119377], dtype=float32),
#   'probabilities': array([0.5302614 , 0.46973857], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14728229], dtype=float32),
#   'logits': array([-1.7560775], dtype=float32),
#   'probabilities': array([0.8527177 , 0.14728227], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37586826], dtype=float32),
#   'logits': array([-0.50712276], dtype=float32),
#   'probabilities': array([0.62413174, 0.37586826], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6762257], dtype=float32),
#   'logits': array([0.7364805], dtype=float32),
#   'probabilities': array([0.32377425, 0.6762257 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5193464], dtype=float32),
#   'logits': array([0.07742441], dtype=float32),
#   'probabilities': array([0.48065355, 0.5193464 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36263898], dtype=float32),
#   'logits': array([-0.5639284], dtype=float32),
#   'probabilities': array([0.63736105, 0.36263898], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5888513], dtype=float32),
#   'logits': array([0.35921872], dtype=float32),
#   'probabilities': array([0.4111487, 0.5888513], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21744007], dtype=float32),
#   'logits': array([-1.2806473], dtype=float32),
#   'probabilities': array([0.78255993, 0.21744007], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20952591], dtype=float32),
#   'logits': array([-1.3277854], dtype=float32),
#   'probabilities': array([0.79047406, 0.20952593], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14373802], dtype=float32),
#   'logits': array([-1.784584], dtype=float32),
#   'probabilities': array([0.856262  , 0.14373803], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29407522], dtype=float32),
#   'logits': array([-0.8756731], dtype=float32),
#   'probabilities': array([0.7059248 , 0.29407522], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4763483], dtype=float32),
#   'logits': array([-0.09467751], dtype=float32),
#   'probabilities': array([0.5236517 , 0.47634828], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6761026], dtype=float32),
#   'logits': array([0.7359178], dtype=float32),
#   'probabilities': array([0.32389745, 0.6761026 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24753484], dtype=float32),
#   'logits': array([-1.1118034], dtype=float32),
#   'probabilities': array([0.7524651 , 0.24753481], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17410316], dtype=float32),
#   'logits': array([-1.556822], dtype=float32),
#   'probabilities': array([0.82589686, 0.17410316], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3924536], dtype=float32),
#   'logits': array([-0.43701017], dtype=float32),
#   'probabilities': array([0.6075464, 0.3924536], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24724641], dtype=float32),
#   'logits': array([-1.1133525], dtype=float32),
#   'probabilities': array([0.7527536 , 0.24724641], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15259844], dtype=float32),
#   'logits': array([-1.7143648], dtype=float32),
#   'probabilities': array([0.8474016 , 0.15259846], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19166596], dtype=float32),
#   'logits': array([-1.4392214], dtype=float32),
#   'probabilities': array([0.80833405, 0.19166596], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13177271], dtype=float32),
#   'logits': array([-1.8853749], dtype=float32),
#   'probabilities': array([0.8682273 , 0.13177271], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43285602], dtype=float32),
#   'logits': array([-0.270208], dtype=float32),
#   'probabilities': array([0.567144  , 0.43285605], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7637167], dtype=float32),
#   'logits': array([1.1731654], dtype=float32),
#   'probabilities': array([0.23628329, 0.7637167 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7597087], dtype=float32),
#   'logits': array([1.1510834], dtype=float32),
#   'probabilities': array([0.24029125, 0.7597087 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5150273], dtype=float32),
#   'logits': array([0.06012738], dtype=float32),
#   'probabilities': array([0.48497266, 0.5150273 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47868708], dtype=float32),
#   'logits': array([-0.08530331], dtype=float32),
#   'probabilities': array([0.5213129, 0.4786871], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56040454], dtype=float32),
#   'logits': array([0.24280393], dtype=float32),
#   'probabilities': array([0.43959552, 0.56040454], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11838584], dtype=float32),
#   'logits': array([-2.0078053], dtype=float32),
#   'probabilities': array([0.88161415, 0.11838584], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.50797874], dtype=float32),
#   'logits': array([0.03191757], dtype=float32),
#   'probabilities': array([0.49202132, 0.50797874], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7592752], dtype=float32),
#   'logits': array([1.1487099], dtype=float32),
#   'probabilities': array([0.24072482, 0.7592752 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39279214], dtype=float32),
#   'logits': array([-0.43559057], dtype=float32),
#   'probabilities': array([0.60720783, 0.39279214], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2977649], dtype=float32),
#   'logits': array([-0.8579639], dtype=float32),
#   'probabilities': array([0.70223504, 0.2977649 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32002214], dtype=float32),
#   'logits': array([-0.75367004], dtype=float32),
#   'probabilities': array([0.67997783, 0.32002214], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56683624], dtype=float32),
#   'logits': array([0.26895452], dtype=float32),
#   'probabilities': array([0.4331638 , 0.56683624], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.252091], dtype=float32),
#   'logits': array([-1.0874913], dtype=float32),
#   'probabilities': array([0.747909, 0.252091], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.63938606], dtype=float32),
#   'logits': array([0.5727004], dtype=float32),
#   'probabilities': array([0.36061397, 0.63938606], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39259815], dtype=float32),
#   'logits': array([-0.436404], dtype=float32),
#   'probabilities': array([0.60740185, 0.39259818], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3967977], dtype=float32),
#   'logits': array([-0.41882604], dtype=float32),
#   'probabilities': array([0.60320234, 0.39679772], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16834168], dtype=float32),
#   'logits': array([-1.5974259], dtype=float32),
#   'probabilities': array([0.8316583 , 0.16834168], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2100751], dtype=float32),
#   'logits': array([-1.3244728], dtype=float32),
#   'probabilities': array([0.78992486, 0.2100751 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20104185], dtype=float32),
#   'logits': array([-1.3797954], dtype=float32),
#   'probabilities': array([0.7989581 , 0.20104186], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.414108], dtype=float32),
#   'logits': array([-0.34700865], dtype=float32),
#   'probabilities': array([0.58589196, 0.41410798], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15615195], dtype=float32),
#   'logits': array([-1.6871428], dtype=float32),
#   'probabilities': array([0.84384805, 0.15615195], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.736927], dtype=float32),
#   'logits': array([1.0300571], dtype=float32),
#   'probabilities': array([0.26307303, 0.736927  ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2146936], dtype=float32),
#   'logits': array([-1.2968621], dtype=float32),
#   'probabilities': array([0.78530645, 0.21469359], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47703463], dtype=float32),
#   'logits': array([-0.09192628], dtype=float32),
#   'probabilities': array([0.52296543, 0.47703463], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16296396], dtype=float32),
#   'logits': array([-1.6363381], dtype=float32),
#   'probabilities': array([0.8370361 , 0.16296396], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.67186457], dtype=float32),
#   'logits': array([0.71663034], dtype=float32),
#   'probabilities': array([0.32813543, 0.67186457], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31502026], dtype=float32),
#   'logits': array([-0.77675223], dtype=float32),
#   'probabilities': array([0.6849797 , 0.31502026], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20747977], dtype=float32),
#   'logits': array([-1.3401842], dtype=float32),
#   'probabilities': array([0.7925202 , 0.20747976], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31951457], dtype=float32),
#   'logits': array([-0.7560035], dtype=float32),
#   'probabilities': array([0.6804854 , 0.31951457], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3635271], dtype=float32),
#   'logits': array([-0.56008804], dtype=float32),
#   'probabilities': array([0.63647294, 0.3635271 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1782446], dtype=float32),
#   'logits': array([-1.528286], dtype=float32),
#   'probabilities': array([0.8217554, 0.1782446], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.69849974], dtype=float32),
#   'logits': array([0.84016395], dtype=float32),
#   'probabilities': array([0.30150026, 0.69849974], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21245588], dtype=float32),
#   'logits': array([-1.310185], dtype=float32),
#   'probabilities': array([0.78754413, 0.2124559 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1841376], dtype=float32),
#   'logits': array([-1.4885623], dtype=float32),
#   'probabilities': array([0.81586236, 0.1841376 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2421081], dtype=float32),
#   'logits': array([-1.1411564], dtype=float32),
#   'probabilities': array([0.7578919, 0.2421081], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43280834], dtype=float32),
#   'logits': array([-0.2704022], dtype=float32),
#   'probabilities': array([0.56719166, 0.43280834], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26580304], dtype=float32),
#   'logits': array([-1.0160218], dtype=float32),
#   'probabilities': array([0.73419696, 0.265803  ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12630033], dtype=float32),
#   'logits': array([-1.934074], dtype=float32),
#   'probabilities': array([0.87369967, 0.12630032], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8289581], dtype=float32),
#   'logits': array([1.5782608], dtype=float32),
#   'probabilities': array([0.17104194, 0.8289581 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6614213], dtype=float32),
#   'logits': array([0.66963446], dtype=float32),
#   'probabilities': array([0.3385787, 0.6614213], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5035346], dtype=float32),
#   'logits': array([0.0141387], dtype=float32),
#   'probabilities': array([0.49646538, 0.5035346 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7222124], dtype=float32),
#   'logits': array([0.9554626], dtype=float32),
#   'probabilities': array([0.27778757, 0.7222124 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1264761], dtype=float32),
#   'logits': array([-1.9324822], dtype=float32),
#   'probabilities': array([0.8735239, 0.1264761], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1548647], dtype=float32),
#   'logits': array([-1.696945], dtype=float32),
#   'probabilities': array([0.84513533, 0.1548647 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23048499], dtype=float32),
#   'logits': array([-1.2055748], dtype=float32),
#   'probabilities': array([0.76951504, 0.23048499], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34835586], dtype=float32),
#   'logits': array([-0.626274], dtype=float32),
#   'probabilities': array([0.6516441 , 0.34835586], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4043164], dtype=float32),
#   'logits': array([-0.38751185], dtype=float32),
#   'probabilities': array([0.5956836 , 0.40431643], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5484423], dtype=float32),
#   'logits': array([0.19437897], dtype=float32),
#   'probabilities': array([0.45155767, 0.5484423 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5436009], dtype=float32),
#   'logits': array([0.17484784], dtype=float32),
#   'probabilities': array([0.45639905, 0.5436009 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37394747], dtype=float32),
#   'logits': array([-0.5153189], dtype=float32),
#   'probabilities': array([0.6260525, 0.3739475], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33285898], dtype=float32),
#   'logits': array([-0.6952825], dtype=float32),
#   'probabilities': array([0.667141  , 0.33285898], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3192754], dtype=float32),
#   'logits': array([-0.7571036], dtype=float32),
#   'probabilities': array([0.68072456, 0.31927544], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19588667], dtype=float32),
#   'logits': array([-1.4122039], dtype=float32),
#   'probabilities': array([0.80411327, 0.19588666], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.61826575], dtype=float32),
#   'logits': array([0.4821937], dtype=float32),
#   'probabilities': array([0.38173425, 0.61826575], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13432746], dtype=float32),
#   'logits': array([-1.8632262], dtype=float32),
#   'probabilities': array([0.8656726 , 0.13432747], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22166464], dtype=float32),
#   'logits': array([-1.2559919], dtype=float32),
#   'probabilities': array([0.7783354 , 0.22166462], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52733165], dtype=float32),
#   'logits': array([0.10943568], dtype=float32),
#   'probabilities': array([0.47266835, 0.52733165], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37686008], dtype=float32),
#   'logits': array([-0.502897], dtype=float32),
#   'probabilities': array([0.62313986, 0.37686008], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20726204], dtype=float32),
#   'logits': array([-1.3415087], dtype=float32),
#   'probabilities': array([0.79273796, 0.20726207], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3034762], dtype=float32),
#   'logits': array([-0.8307987], dtype=float32),
#   'probabilities': array([0.6965238, 0.3034762], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2824011], dtype=float32),
#   'logits': array([-0.93258226], dtype=float32),
#   'probabilities': array([0.71759886, 0.2824011 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14433378], dtype=float32),
#   'logits': array([-1.7797518], dtype=float32),
#   'probabilities': array([0.8556663, 0.1443338], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21851788], dtype=float32),
#   'logits': array([-1.2743243], dtype=float32),
#   'probabilities': array([0.7814821, 0.2185179], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5519957], dtype=float32),
#   'logits': array([0.2087375], dtype=float32),
#   'probabilities': array([0.44800428, 0.5519957 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6741756], dtype=float32),
#   'logits': array([0.72713196], dtype=float32),
#   'probabilities': array([0.32582444, 0.6741756 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6224931], dtype=float32),
#   'logits': array([0.50014365], dtype=float32),
#   'probabilities': array([0.3775069, 0.6224931], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.68841964], dtype=float32),
#   'logits': array([0.7927413], dtype=float32),
#   'probabilities': array([0.31158036, 0.68841964], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42105985], dtype=float32),
#   'logits': array([-0.3184241], dtype=float32),
#   'probabilities': array([0.57894015, 0.42105985], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27432546], dtype=float32),
#   'logits': array([-0.97278637], dtype=float32),
#   'probabilities': array([0.7256745 , 0.27432546], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49087292], dtype=float32),
#   'logits': array([-0.03651226], dtype=float32),
#   'probabilities': array([0.5091271 , 0.49087298], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20379359], dtype=float32),
#   'logits': array([-1.3627508], dtype=float32),
#   'probabilities': array([0.7962064 , 0.20379359], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16444866], dtype=float32),
#   'logits': array([-1.6254933], dtype=float32),
#   'probabilities': array([0.8355513 , 0.16444868], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19934492], dtype=float32),
#   'logits': array([-1.3903936], dtype=float32),
#   'probabilities': array([0.80065507, 0.19934493], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48134974], dtype=float32),
#   'logits': array([-0.07463562], dtype=float32),
#   'probabilities': array([0.5186503 , 0.48134977], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.05766068], dtype=float32),
#   'logits': array([-2.7937899], dtype=float32),
#   'probabilities': array([0.94233924, 0.05766068], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2891557], dtype=float32),
#   'logits': array([-0.8994881], dtype=float32),
#   'probabilities': array([0.7108443, 0.2891557], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17954135], dtype=float32),
#   'logits': array([-1.5194579], dtype=float32),
#   'probabilities': array([0.82045865, 0.17954136], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23413374], dtype=float32),
#   'logits': array([-1.1851151], dtype=float32),
#   'probabilities': array([0.7658662 , 0.23413374], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26768303], dtype=float32),
#   'logits': array([-1.0064099], dtype=float32),
#   'probabilities': array([0.732317  , 0.26768303], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30348232], dtype=float32),
#   'logits': array([-0.8307698], dtype=float32),
#   'probabilities': array([0.69651765, 0.30348232], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.76122713], dtype=float32),
#   'logits': array([1.159419], dtype=float32),
#   'probabilities': array([0.2387729 , 0.76122713], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19015586], dtype=float32),
#   'logits': array([-1.4489977], dtype=float32),
#   'probabilities': array([0.80984414, 0.19015586], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13224752], dtype=float32),
#   'logits': array([-1.8812312], dtype=float32),
#   'probabilities': array([0.86775243, 0.13224752], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60127264], dtype=float32),
#   'logits': array([0.41077054], dtype=float32),
#   'probabilities': array([0.3987274 , 0.60127264], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45498434], dtype=float32),
#   'logits': array([-0.18055159], dtype=float32),
#   'probabilities': array([0.5450157 , 0.45498434], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.84602493], dtype=float32),
#   'logits': array([1.7037579], dtype=float32),
#   'probabilities': array([0.15397511, 0.84602493], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6212623], dtype=float32),
#   'logits': array([0.49490964], dtype=float32),
#   'probabilities': array([0.37873766, 0.6212623 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13334563], dtype=float32),
#   'logits': array([-1.8716958], dtype=float32),
#   'probabilities': array([0.8666544 , 0.13334565], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6124021], dtype=float32),
#   'logits': array([0.4574207], dtype=float32),
#   'probabilities': array([0.38759786, 0.6124021 ], dtype=float32)}]

# %%
# dense neural network classifier
dnn_model =tf.estimator.DNNClassifier(hidden_units=[10,10,10], feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Dennis\AppData\Local\Temp\tmpj59nn5dh
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Dennis\\AppData\\Local\\Temp\\tmpj59nn5dh', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000020092B9BCC0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
embedded_group_col = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg, plasma_gluc, dias_press, tricep, insulin, bmi, diabetes_pedigree, embedded_group_col, age_bucket]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(X_train, y_train, batch_size=10, num_epochs=1000, shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10], feature_columns=feat_cols, n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\Dennis\AppData\Local\Temp\tmp5nv1oz9j
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\Dennis\\AppData\\Local\\Temp\\tmp5nv1oz9j', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002008FE66630>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func, steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\Dennis\AppData\Local\Temp\tmp5nv1oz9j\model.ckpt.
# INFO:tensorflow:loss = 6.207384, step = 1
# INFO:tensorflow:global_step/sec: 469.241
# INFO:tensorflow:loss = 5.767208, step = 101 (0.215 sec)
# INFO:tensorflow:global_step/sec: 828.639
# INFO:tensorflow:loss = 4.7872744, step = 201 (0.122 sec)
# INFO:tensorflow:global_step/sec: 789.513
# INFO:tensorflow:loss = 3.0870638, step = 301 (0.125 sec)
# INFO:tensorflow:global_step/sec: 808.79
# INFO:tensorflow:loss = 6.0708857, step = 401 (0.125 sec)
# INFO:tensorflow:global_step/sec: 771.232
# INFO:tensorflow:loss = 3.3676858, step = 501 (0.130 sec)
# INFO:tensorflow:global_step/sec: 856.881
# INFO:tensorflow:loss = 4.703823, step = 601 (0.119 sec)
# INFO:tensorflow:global_step/sec: 815.166
# INFO:tensorflow:loss = 4.393614, step = 701 (0.122 sec)
# INFO:tensorflow:global_step/sec: 765.378
# INFO:tensorflow:loss = 5.3337145, step = 801 (0.130 sec)
# INFO:tensorflow:global_step/sec: 789.547
# INFO:tensorflow:loss = 5.5973716, step = 901 (0.127 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\Dennis\AppData\Local\Temp\tmp5nv1oz9j\model.ckpt.
# INFO:tensorflow:Loss for final step: 3.2392347.

# %%
eval_input_fn = tf.estimator.inputs.pandas_input_fn(x=X_test, y=y_test, batch_size=10, num_epochs=1, shuffle=False)

# %%
dnn_model.evaluate(eval_input_fn)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-06-07-03:49:00
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\Dennis\AppData\Local\Temp\tmp5nv1oz9j\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-06-07-03:49:01
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.76623374, accuracy_baseline = 0.64935064, auc = 0.82835394, auc_precision_recall = 0.70714104, average_loss = 0.49178976, global_step = 1000, label/mean = 0.35064936, loss = 4.733476, precision = 0.70149255, prediction/mean = 0.31105396, recall = 0.5802469
# {'accuracy': 0.76623374,
#  'accuracy_baseline': 0.64935064,
#  'auc': 0.82835394,
#  'auc_precision_recall': 0.70714104,
#  'average_loss': 0.49178976,
#  'global_step': 1000,
#  'label/mean': 0.35064936,
#  'loss': 4.733476,
#  'precision': 0.70149255,
#  'prediction/mean': 0.31105396,
#  'recall': 0.5802469}
